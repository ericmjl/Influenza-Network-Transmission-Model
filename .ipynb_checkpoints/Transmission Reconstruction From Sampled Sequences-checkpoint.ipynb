# %%
import numpy as np
import pandas as pd
import networkx as nx

# %%
segment0 = pd.read_csv('Similarity Matrices/Model 2 Segment 0 Sampled.csv', index_col=0)
segment1 = pd.read_csv('Similarity Matrices/Model 2 Segment 1 Sampled.csv', index_col=0)

# %%
np.fill_diagonal(segment0.as_matrix(), 0)
np.fill_diagonal(segment1.as_matrix(), 0)

# %%
segment0
# Out:
#      14    4   17    9   15   16   11   12   19    7
# 14    0  299  299  298  300  297  299  299  298  300
# 4   299    0  298  299  299  298  300  300  297  299
# 17  299  298    0  297  299  296  298  298  297  299
# 9   298  299  297    0  298  297  299  299  296  298
# 15  300  299  299  298    0  297  299  299  298  300
# 16  297  298  296  297  297    0  298  298  295  297
# 11  299  300  298  299  299  298    0  300  297  299
# 12  299  300  298  299  299  298  300    0  297  299
# 19  298  297  297  296  298  295  297  297    0  298
# 7   300  299  299  298  300  297  299  299  298    0
#
# [10 rows x 10 columns]

# %%
segment1
# Out:
#      14    4   17    9   15   16   11   12   19    7
# 14    0  278  298  261  278  268  268  263  279  297
# 4   278    0  278  278  259  279  279  277  261  277
# 17  298  278    0  260  276  268  266  263  279  297
# 9   261  278  260    0  250  263  263  267  247  259
# 15  278  259  276  250    0  249  254  249  264  279
# 16  268  279  268  263  249    0  264  261  258  267
# 11  268  279  266  263  254  264    0  265  259  265
# 12  263  277  263  267  249  261  265    0  251  262
# 19  279  261  279  247  264  258  259  251    0  276
# 7   297  277  297  259  279  267  265  262  276    0
#
# [10 rows x 10 columns]

# %%
summed = segment0.as_matrix() + segment1.as_matrix()
summed = summed / 600.0
summed = np.triu(summed)

# %%
G = nx.from_numpy_matrix(summed, create_using=nx.MultiDiGraph())
G
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-4f73b13156a6> in <module>()
# ----> 1 G = nx.from_numpy_matrix(segments.as_matrix(), create_using=nx.MultiDiGraph())
#       2 G
#
# NameError: name 'segments' is not defined

# %%
G.edges(data=True)

# %%
G.in_edges(3, data=True)

# %%
max(edge[2]['weight'] for edge in G.in_edges(3, data=True))

# %%
for node in G.nodes():
    edges = G.in_edges(node, data=True)
#     print "edges are: %s" % edges
    if len(edges) > 0:
        max_weight = max([edge[2]['weight'] for edge in edges])
        for edge in edges:
#             print "max_weight is: %s" % max_weight
            if edge[2]['weight'] < max_weight:
#                 print "removing edge %s->%s which has weight %s" % (edge[0], edge[1], edge[2]['weight'])
                G.remove_edge(edge[0], edge[1])

# %%
max(edge[2]['weight'] for edge in G.in_edges(3, data=True))

# %%
nx.draw_circular(G)
