# %% [markdown]
# # Introduction
#
# In this notebook, the goal is to explicitly model the simplest process that can happen within an environment containing influenza viruses. Here, the following parameters are used:
#
# 1. Only 1 smallfluvirus seeding.
# 2. No reassortments happen.
# 3. At each time step, perform replication according to SeqTrack simulation parameters.
# 4. Stop replicating when population size = 20
#
# At the end, we do two things:
#
# 1. Dump all sequences out.
# 2. Sample 50 sequences, and dump those.

# %%
from environment import Environment
from sampler import Sampler
from random import random

# %%
e = Environment(num_viruses=1, virus_type='influenza')
# Out:
# [287]
# [275, 287, 207, 283, 248, 295, 222, 215, 231, 258, 205, 229, 279, 256, 221, 259, 249, 214, 263, 219]
# [5]

# %%
while len(e.GetViruses()) < 20:
    cointoss = random()
    print cointoss
    
    # 50% probability of replicating while mutating in the variable region and single position anywhere.
    if cointoss < 0.5:
        e.ReplicateAVirus(mutate=True, mutate_variable_region=True)
    
    # 50% probability of replicating while mutating single position anywhere
    if cointoss >= 0.5:
        e.ReplicateAVirus(mutate=True)
# Out:
# 0.593139544948
# [159]
# 0.580316107668
# [180]
# 0.0946446312483
# The virus is a Small Flu Virus.
# [114]
# [261, 244, 229, 254, 208, 230, 282, 285, 220, 238, 204, 206, 293, 219, 231, 237, 259, 265, 217, 246]
# 0.536013783709
# [257]
# 0.617590940094
# [101]
# 0.262379324355
# The virus is a Small Flu Virus.
# [211]
# [207, 291, 229, 235, 290, 219, 228, 241, 218, 295, 200, 250, 260, 285, 272, 205, 223, 210, 202, 222]
# 0.691906431977
# [49]
# 0.666810890641
# [119]
# 0.453427456629
# The virus is a Small Flu Virus.
# [244]
# [296, 209, 276, 286, 200, 221, 211, 212, 256, 233, 251, 218, 226, 244, 223, 224, 240, 248, 294, 274]
# 0.0139554949118
# The virus is a Small Flu Virus.
# [41]
# [271, 214, 243, 228, 292, 246, 295, 257, 201, 247, 277, 213, 227, 232, 256, 242, 237, 276, 215, 280]
# 0.37610401265
# The virus is a Small Flu Virus.
# [265]
# [219, 202, 237, 263, 232, 230, 207, 295, 274, 223, 273, 278, 265, 200, 253, 262, 206, 225, 250, 214]
# 0.20476944606
# The virus is a Small Flu Virus.
# [227]
# [269, 234, 224, 253, 248, 206, 212, 260, 207, 205, 246, 244, 216, 278, 274, 231, 277, 250, 247, 270]
# 0.917729596748
# [94]
# 0.534759527235
# [200]
# 0.00174638838038
# The virus is a Small Flu Virus.
# [167]
# [215, 299, 273, 240, 238, 251, 203, 293, 296, 232, 250, 218, 274, 216, 243, 285, 298, 205, 200, 228]
# 0.0316166429807
# The virus is a Small Flu Virus.
# [222]
# [272, 235, 229, 223, 264, 265, 288, 208, 284, 280, 270, 291, 209, 231, 222, 202, 220, 214, 233, 234]
# 0.603754326101
# [166]
# 0.0712839843795
# The virus is a Small Flu Virus.
# [29]
# [229, 201, 298, 217, 234, 259, 204, 220, 251, 246, 231, 267, 295, 258, 222, 296, 226, 286, 257, 215]
# 0.767555895208
# [151]

# %%
len(e.GetViruses())
# Out:
# 20

# %%
s = Sampler()
s.SampleVirusesFromEnvironment(e, 'all')
s.DumpSequences()

# %%
s.GenerateNetworkVisualization()

# %%
s.SampleVirusesFromEnvironment(e, 10)
s.DumpSequences()

# %%
s.GenerateNetworkVisualization()
