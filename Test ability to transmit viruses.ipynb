# %%
from controller import Controller

# %%
c = Controller()
c.create_environment(num_hosts=100)
i = 0
for host in c.environments[0].hosts:
    if i < 5:
        c.create_virus(host)
        i += 1

# %%
timesteps = range(50)

num_infected_hosts = []

for i in timesteps:
    c.increment_timestep()
    c.make_many_infections_happen(c.environments[0], 1)
    num_infected_hosts.append(c.get_num_of_infected_hosts(c.environments[0]))
# Out:
# Removing 0 viruses out of 1 viruses.
# Removing 0 viruses out of 1 viruses.
# Removing 0 viruses out of 1 viruses.
# Removing 0 viruses out of 1 viruses.
# Removing 8 viruses out of 13 viruses.
# Host 89d8fe471248842f70407779fc2447aed092fdca99e65217b563c792299908082df547f2f5cb5eb54faeba67fdbcf9e11cb075ad73e8e3e82fee8997fdba7040 infected with 1 viruses
# Host cd091c88b154c8a46d191ce7ce72327952b1b37031b53b457887d89853efc950be3f6f854e3a9c76c218dd78df51267c97b518e9817b1cb8038b020152d2fc59 infected with 1 viruses
# Host c40c20eac8d9800a6898ec29f86082dd1585f47aa741536e1bb67073064441aafacc14c9a7baf408e87027c32040d703ecb9d1df487b4921ad6a5c31ca9b902b infected with 1 viruses
# Host a0ef57c5d58d43e74861838cff7c4117a0a6a3b3a066ad79d804e236799b41979258ea1e78a0373fc24ef560d38b6fac611b756ac92508d931d0699f2253ae41 infected with 1 viruses
# Host 874f6628f2fb3ad69dae73c309aacad8a6901878d25a99c5939892194f4d08b7627171b6e34e0f876bc256b56c6eff764b5f67b48e98f6ee54115d491e0caf20 infected with 5 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Removing 3 viruses out of 13 viruses.
# Removing 3 viruses out of 7 viruses.
# Removing 3 viruses out of 7 viruses.
# Removing 0 viruses out of 1 viruses.
# Removing 9 viruses out of 17 viruses.
# Host 89d8fe471248842f70407779fc2447aed092fdca99e65217b563c792299908082df547f2f5cb5eb54faeba67fdbcf9e11cb075ad73e8e3e82fee8997fdba7040 infected with 1 viruses
# Host cd091c88b154c8a46d191ce7ce72327952b1b37031b53b457887d89853efc950be3f6f854e3a9c76c218dd78df51267c97b518e9817b1cb8038b020152d2fc59 infected with 4 viruses
# Host c40c20eac8d9800a6898ec29f86082dd1585f47aa741536e1bb67073064441aafacc14c9a7baf408e87027c32040d703ecb9d1df487b4921ad6a5c31ca9b902b infected with 4 viruses
# Host a0ef57c5d58d43e74861838cff7c4117a0a6a3b3a066ad79d804e236799b41979258ea1e78a0373fc24ef560d38b6fac611b756ac92508d931d0699f2253ae41 infected with 1 viruses
# Host 874f6628f2fb3ad69dae73c309aacad8a6901878d25a99c5939892194f4d08b7627171b6e34e0f876bc256b56c6eff764b5f67b48e98f6ee54115d491e0caf20 infected with 8 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host 0f11ea9febca1d8da66f592dd6c5780cd3d021a294eac8596d6724a56ac48ac42eb24df9351c067a1436a2d211b046150449fbe56457d1f1b454320b311fd4b0 infected with 9 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Removing 3 viruses out of 7 viruses.
# Removing 15 viruses out of 24 viruses.
# Removing 19 viruses out of 30 viruses.
# Removing 5 viruses out of 11 viruses.
# Removing 10 viruses out of 16 viruses.
# Removing 2 viruses out of 9 viruses.
# Host 89d8fe471248842f70407779fc2447aed092fdca99e65217b563c792299908082df547f2f5cb5eb54faeba67fdbcf9e11cb075ad73e8e3e82fee8997fdba7040 infected with 38 viruses
# Host cd091c88b154c8a46d191ce7ce72327952b1b37031b53b457887d89853efc950be3f6f854e3a9c76c218dd78df51267c97b518e9817b1cb8038b020152d2fc59 infected with 9 viruses
# Host c40c20eac8d9800a6898ec29f86082dd1585f47aa741536e1bb67073064441aafacc14c9a7baf408e87027c32040d703ecb9d1df487b4921ad6a5c31ca9b902b infected with 11 viruses
# Host a0ef57c5d58d43e74861838cff7c4117a0a6a3b3a066ad79d804e236799b41979258ea1e78a0373fc24ef560d38b6fac611b756ac92508d931d0699f2253ae41 infected with 6 viruses
# Host 874f6628f2fb3ad69dae73c309aacad8a6901878d25a99c5939892194f4d08b7627171b6e34e0f876bc256b56c6eff764b5f67b48e98f6ee54115d491e0caf20 infected with 6 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host adc379e0b02fbf0c598ae76a99096b6a6fa7f43c41e042b183628e817fe19cc7d5ed7fedb6cd7d01d8fce4530b0d517112e921e4cfa44866bc76aaa99ffc5c9b infected with 6 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host 0f11ea9febca1d8da66f592dd6c5780cd3d021a294eac8596d6724a56ac48ac42eb24df9351c067a1436a2d211b046150449fbe56457d1f1b454320b311fd4b0 infected with 1 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Removing 138 viruses out of 206 viruses.
# Removing 22 viruses out of 43 viruses.
# Removing 37 viruses out of 53 viruses.
# Removing 11 viruses out of 16 viruses.
# Removing 5 viruses out of 6 viruses.
# Removing 1 viruses out of 6 viruses.
# Removing 1 viruses out of 1 viruses.
# Host 89d8fe471248842f70407779fc2447aed092fdca99e65217b563c792299908082df547f2f5cb5eb54faeba67fdbcf9e11cb075ad73e8e3e82fee8997fdba7040 infected with 92 viruses
# Host cd091c88b154c8a46d191ce7ce72327952b1b37031b53b457887d89853efc950be3f6f854e3a9c76c218dd78df51267c97b518e9817b1cb8038b020152d2fc59 infected with 21 viruses
# Host c40c20eac8d9800a6898ec29f86082dd1585f47aa741536e1bb67073064441aafacc14c9a7baf408e87027c32040d703ecb9d1df487b4921ad6a5c31ca9b902b infected with 16 viruses
# Host a0ef57c5d58d43e74861838cff7c4117a0a6a3b3a066ad79d804e236799b41979258ea1e78a0373fc24ef560d38b6fac611b756ac92508d931d0699f2253ae41 infected with 5 viruses
# Host 874f6628f2fb3ad69dae73c309aacad8a6901878d25a99c5939892194f4d08b7627171b6e34e0f876bc256b56c6eff764b5f67b48e98f6ee54115d491e0caf20 infected with 1 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host adc379e0b02fbf0c598ae76a99096b6a6fa7f43c41e042b183628e817fe19cc7d5ed7fedb6cd7d01d8fce4530b0d517112e921e4cfa44866bc76aaa99ffc5c9b infected with 5 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host f80e032eb8b0d53b32a4419ee71376264293e74d69e0232d9696ca8095226f6724c6b580e5c28520d0e488cbf86299469c3f4bd339dda1e9f2c2beafed724b2c infected with 8 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Removing 233 viruses out of 338 viruses.
# Removing 155 viruses out of 221 viruses.
# Removing 126 viruses out of 176 viruses.
# Removing 35 viruses out of 43 viruses.
# Removing 1 viruses out of 1 viruses.
# Removing 2 viruses out of 5 viruses.
# Removing 4 viruses out of 8 viruses.
# Host 89d8fe471248842f70407779fc2447aed092fdca99e65217b563c792299908082df547f2f5cb5eb54faeba67fdbcf9e11cb075ad73e8e3e82fee8997fdba7040 infected with 219 viruses
# Host cd091c88b154c8a46d191ce7ce72327952b1b37031b53b457887d89853efc950be3f6f854e3a9c76c218dd78df51267c97b518e9817b1cb8038b020152d2fc59 infected with 66 viruses
# Host c40c20eac8d9800a6898ec29f86082dd1585f47aa741536e1bb67073064441aafacc14c9a7baf408e87027c32040d703ecb9d1df487b4921ad6a5c31ca9b902b infected with 50 viruses
# Host a0ef57c5d58d43e74861838cff7c4117a0a6a3b3a066ad79d804e236799b41979258ea1e78a0373fc24ef560d38b6fac611b756ac92508d931d0699f2253ae41 infected with 2 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host cf5bd028d70e162da05882e6692296e7323d355d392072855133b4d54721bca4b06a1ed9849611832d112ab527490f45d2e9895f7794f7048d055ba4604b9922 infected with 6 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host adc379e0b02fbf0c598ae76a99096b6a6fa7f43c41e042b183628e817fe19cc7d5ed7fedb6cd7d01d8fce4530b0d517112e921e4cfa44866bc76aaa99ffc5c9b infected with 3 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host f80e032eb8b0d53b32a4419ee71376264293e74d69e0232d9696ca8095226f6724c6b580e5c28520d0e488cbf86299469c3f4bd339dda1e9f2c2beafed724b2c infected with 4 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Removing 230 viruses out of 301 viruses.
# Removing 371 viruses out of 496 viruses.
# Removing 152 viruses out of 198 viruses.
# Removing 2 viruses out of 2 viruses.
# Removing 2 viruses out of 6 viruses.
# Removing 3 viruses out of 3 viruses.
# Removing 2 viruses out of 4 viruses.
# Host 89d8fe471248842f70407779fc2447aed092fdca99e65217b563c792299908082df547f2f5cb5eb54faeba67fdbcf9e11cb075ad73e8e3e82fee8997fdba7040 infected with 115 viruses
# Host cd091c88b154c8a46d191ce7ce72327952b1b37031b53b457887d89853efc950be3f6f854e3a9c76c218dd78df51267c97b518e9817b1cb8038b020152d2fc59 infected with 117 viruses
# Host c40c20eac8d9800a6898ec29f86082dd1585f47aa741536e1bb67073064441aafacc14c9a7baf408e87027c32040d703ecb9d1df487b4921ad6a5c31ca9b902b infected with 46 viruses
# Host a0ef57c5d58d43e74861838cff7c4117a0a6a3b3a066ad79d804e236799b41979258ea1e78a0373fc24ef560d38b6fac611b756ac92508d931d0699f2253ae41 infected with 56 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host cf5bd028d70e162da05882e6692296e7323d355d392072855133b4d54721bca4b06a1ed9849611832d112ab527490f45d2e9895f7794f7048d055ba4604b9922 infected with 4 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host f80e032eb8b0d53b32a4419ee71376264293e74d69e0232d9696ca8095226f6724c6b580e5c28520d0e488cbf86299469c3f4bd339dda1e9f2c2beafed724b2c infected with 2 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host f5785b146801d276dcf62c27445362a8bce60b6d37cdafa07553b69f0cff3ec55c4d7653123cff4510c660104b9962f1804103a0a0bc5d6a501a4f88e8ce9530 infected with 8 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Removing
viruses
# Host c40c20eac8d9800a6898ec29f86082dd1585f47aa741536e1bb67073064441aafacc14c9a7baf408e87027c32040d703ecb9d1df487b4921ad6a5c31ca9b902b infected with 128 viruses
# Host a0ef57c5d58d43e74861838cff7c4117a0a6a3b3a066ad79d804e236799b41979258ea1e78a0373fc24ef560d38b6fac611b756ac92508d931d0699f2253ae41 infected with 7 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host 01b3e529e96b8eeb3a68cee40510abb61e90dcaa9c7961a559017e1837c052acd536287e5396183912b350422dccdf1e4255e39a24f980b7713765f1b820efc7 infected with 10 viruses
# Host currently uninfected.
# ...
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host 939b188450e9303978665abc45e8edc5778000e95446e9f6941e954d3b2aed774bf61d5964b2a4c4b5182160b674fbc3de911447f682ec92280b430c3535eebc infected with 1 viruses
# Host e2fd95e221a68a228ce576856d40f0d70caf7bbb266b89a8d9f5736d9b9e8a0a7ffc855bc0cb382d4328c04e47923764eba8ac7435efaf1e665b672ee9ca51ff infected with 1 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Removing 115 viruses out of 128 viruses.
# Removing 72 viruses out of 91 viruses.
# Removing 16 viruses out of 17 viruses.
# Removing 8 viruses out of 8 viruses.
# Removing 1 viruses out of 1 viruses.
# Removing 0 viruses out of 1 viruses.
# Host 89d8fe471248842f70407779fc2447aed092fdca99e65217b563c792299908082df547f2f5cb5eb54faeba67fdbcf9e11cb075ad73e8e3e82fee8997fdba7040 infected with 21 viruses
# Host cd091c88b154c8a46d191ce7ce72327952b1b37031b53b457887d89853efc950be3f6f854e3a9c76c218dd78df51267c97b518e9817b1cb8038b020152d2fc59 infected with 19 viruses
# Host c40c20eac8d9800a6898ec29f86082dd1585f47aa741536e1bb67073064441aafacc14c9a7baf408e87027c32040d703ecb9d1df487b4921ad6a5c31ca9b902b infected with 1 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host e2fd95e221a68a228ce576856d40f0d70caf7bbb266b89a8d9f5736d9b9e8a0a7ffc855bc0cb382d4328c04e47923764eba8ac7435efaf1e665b672ee9ca51ff infected with 1 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Removing 196 viruses out of 221 viruses.
# Removing 142 viruses out of 157 viruses.
# Removing 1 viruses out of 1 viruses.
# Removing 1 viruses out of 1 viruses.
# Host 89d8fe471248842f70407779fc2447aed092fdca99e65217b563c792299908082df547f2f5cb5eb54faeba67fdbcf9e11cb075ad73e8e3e82fee8997fdba7040 infected with 33 viruses
# Host cd091c88b154c8a46d191ce7ce72327952b1b37031b53b457887d89853efc950be3f6f854e3a9c76c218dd78df51267c97b518e9817b1cb8038b020152d2fc59 infected with 7 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host a05e35468b32663bcaaada2c9d26aa1adb04a8c0852caa5431e4fb0401b51436db0262d6d69ff6604a25f54ee90295f5b41abf2d9b921692b95a2c2e4f76d43c infected with 8 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Removing 350 viruses out of 389 viruses.
# Removing 50 viruses out of 57 viruses.
# Removing 4 viruses out of 8 viruses.
# Host 89d8fe471248842f70407779fc2447aed092fdca99e65217b563c792299908082df547f2f5cb5eb54faeba67fdbcf9e11cb075ad73e8e3e82fee8997fdba7040 infected with 33 viruses
# Host cd091c88b154c8a46d191ce7ce72327952b1b37031b53b457887d89853efc950be3f6f854e3a9c76c218dd78df51267c97b518e9817b1cb8038b020152d2fc59 infected with 39 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host a05e35468b32663bcaaada2c9d26aa1adb04a8c0852caa5431e4fb0401b51436db0262d6d69ff6604a25f54ee90295f5b41abf2d9b921692b95a2c2e4f76d43c infected with 4 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host c6e1c13d29fba2ea2c79ac712ea6bccb1289ac6a4caf36fc8a7983c5c2e63294a352b3f6bbdf4cfe4baa794dd8d62bc1b8513c1dca97df05c54fd473e91de2f2 infected with 6 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Removing 138 viruses out of 153 viruses.
# Removing 234 viruses out of 263 viruses.
# Removing 1 viruses out of 4 viruses.
# Removing 3 viruses out of 6 viruses.
# Host 89d8fe471248842f70407779fc2447aed092fdca99e65217b563c792299908082df547f2f5cb5eb54faeba67fdbcf9e11cb075ad73e8e3e82fee8997fdba7040 infected with 13 viruses
# Host cd091c88b154c8a46d191ce7ce72327952b1b37031b53b457887d89853efc950be3f6f854e3a9c76c218dd78df51267c97b518e9817b1cb8038b020152d2fc59 infected with 39 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host a05e35468b32663bcaaada2c9d26aa1adb04a8c0852caa5431e4fb0401b51436db0262d6d69ff6604a25f54ee90295f5b41abf2d9b921692b95a2c2e4f76d43c infected with 3 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host d0766689893c6e5a25ba6bd28e15a66fa4bbed8f1123b74deaf34dd2680abfab3556c85ad5b8621324af116fa57c84cf346fcddd171d43f54e7cfa7c2a2f0894 infected with 8 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.
# Host c6e1c13d29fba2ea2c79ac712ea6bccb1289ac6a4caf36fc8a7983c5c2e63294a352b3f6bbdf4cfe4baa794dd8d62bc1b8513c1dca97df05c54fd473e91de2f2 infected with 3 viruses
# Host currently uninfected.
# Host currently uninfected.
# Host currently uninfected.

# %%
print num_infected_hosts
# Out:
# [5, 6, 7, 7, 7, 7, 7, 7, 6, 7, 7, 6, 6, 7, 7, 6, 4, 3, 4, 5]

# %%
plt.plot(num_infected_hosts)
